# %%
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import T5ForConditionalGeneration, T5Tokenizer, AdamW, Trainer, TrainingArguments
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import T5Tokenizer
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('datasets_combine.csv')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Dataset class
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_attention_mask=False,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'label': torch.tensor(label, dtype=torch.long)
        }

# LSTM Classifier Model
class LSTMClassifier(nn.Module):
    def __init__(self, embedding_dim, hidden_dim, vocab_size, output_dim):
        super(LSTMClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, input_ids):
        embedded = self.embedding(input_ids)
        lstm_out, (hidden, _) = self.lstm(embedded)
        out = self.fc(hidden[-1])
        return out

def validate(model, val_loader, criterion, device):
    model.eval()
    total_loss = 0
    correct_predictions = 0
    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch['input_ids'].to(device)
            labels = batch['label'].to(device)
            outputs = model(input_ids)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs, dim=1)
            correct_predictions += (predicted == labels).sum().item()

    avg_loss = total_loss / len(val_loader)
    accuracy = correct_predictions / len(val_loader.dataset)
    return avg_loss, accuracy

# %%
# Model hyperparameters
EMBEDDING_DIM = 100
HIDDEN_DIM = 128
OUTPUT_DIM = 2  # Adjust based on the number of target classes
num_epoch = 8

# Initialize T5 tokenizer
tokenizer = T5Tokenizer.from_pretrained('t5-small')
VOCAB_SIZE = tokenizer.vocab_size

# Prepare the dataset and dataloader
train_texts, val_texts, train_labels, val_labels = train_test_split(df['sentence'], df['label'], test_size=0.2)
train_dataset = TextDataset(train_texts.tolist(), train_labels.tolist(), tokenizer, max_length=128)
val_dataset = TextDataset(val_texts.tolist(), val_labels.tolist(), tokenizer, max_length=128)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Initialize the model
model = LSTMClassifier(EMBEDDING_DIM, HIDDEN_DIM, VOCAB_SIZE, OUTPUT_DIM).to(device)

# Training setup
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop
for epoch in range(num_epoch):  # Number of epochs
    model.train()
    total_loss = 0
    for batch in train_loader:
        input_ids = batch['input_ids'].to(device)
        labels = batch['label'].to(device)
        optimizer.zero_grad()
        predictions = model(input_ids)
        loss = criterion(predictions, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    val_loss, val_accuracy = validate(model, val_loader, criterion, device)
    print(f'Epoch: {epoch + 1}, Loss: {total_loss / len(train_loader)}')
    print(f'Val Loss: {val_loss}, Val Accuracy: {val_accuracy}')
# Save the model
torch.save(model.state_dict(), 'lstm_model.pth')
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Epoch: 1, Loss: 0.6130719469695152
# Val Loss: 0.26568746017386213, Val Accuracy: 0.9242472266244057
# Epoch: 2, Loss: 0.21097844106298458
# Val Loss: 0.1300316272548052, Val Accuracy: 0.961648177496038
# Epoch: 3, Loss: 0.09846173614923713
# Val Loss: 0.11061033756105286, Val Accuracy: 0.9527733755942948
# Epoch: 4, Loss: 0.059507502468090646
# Val Loss: 0.07550806254901067, Val Accuracy: 0.974960380348653
# Epoch: 5, Loss: 0.02863456949479642
# Val Loss: 0.07745197082921448, Val Accuracy: 0.9733755942947702
# Epoch: 6, Loss: 0.011867892306704734
# Val Loss: 0.06674534637031776, Val Accuracy: 0.9812995245641838
# Epoch: 7, Loss: 0.005001046458447847
# Val Loss: 0.07431038403048679, Val Accuracy: 0.9828843106180666
# Epoch: 8, Loss: 0.007853714846475403
# Val Loss: 0.07027959531746955, Val Accuracy: 0.9765451664025356

# %%
def predict(text, model=model, tokenizer=tokenizer, device=device):
    model.eval()
    with torch.no_grad():
        encoding = tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=128,
            padding='max_length',
            truncation=True,
            return_attention_mask=False,
            return_tensors='pt'
        )
        input_ids = encoding['input_ids'].flatten().to(device)
        outputs = model(input_ids)

        # normalize the scores to all positive and sum to 1
        outputs = torch.nn.functional.softmax(outputs, dim=0)

        return outputs

# %%
df = pd.read_csv('datasets_combine.csv')
df, test_df = train_test_split(df, test_size=0.1, random_state=42)

# %%
def prepare_data(df):
    t5_data = []
    for index, row in df.iterrows():
        sentence = row['sentence']
        prompt = "Generate Shakespearean style:" if row['label'] == 1 else "Generate News style:"
        t5_data.append({
            'encoder_input': sentence,
            'decoder_input': prompt,
            'labels': sentence,
            'target_labels': row['label']
        })
    return t5_data

t5_data = prepare_data(df)

# %%
def mask_tokens(inputs, tokenizer, mlm_probability=0.15):
    labels = inputs.clone()
    probability_matrix = torch.full(labels.shape, mlm_probability)
    special_tokens_mask = [
        tokenizer.get_special_tokens_mask(val, already_has_special_tokens=True) for val in labels.tolist()
    ]
    probability_matrix.masked_fill_(torch.tensor(special_tokens_mask, dtype=torch.bool), value=0.0)
    masked_indices = torch.bernoulli(probability_matrix).bool()
    labels[~masked_indices] = -100  # Only compute loss on masked tokens

    mask_token_id = tokenizer.convert_tokens_to_ids(tokenizer.additional_special_tokens[0])
    inputs[masked_indices] = mask_token_id

    return inputs, labels

# %%
class T5StyleTransferDataset(Dataset):
    def __init__(self, tokenizer, data, max_length=512):
        self.tokenizer = tokenizer
        self.data = data
        self.max_length = max_length
        self.target_labels = [item['target_labels'] for item in self.data]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]

        # Encoding for T5 input (encoder)
        encoder_input = item['encoder_input']
        encoder_encoding = self.tokenizer(
            encoder_input,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors="pt"
        )

        # Apply masking
        input_ids, labels = mask_tokens(encoder_encoding.input_ids, self.tokenizer)

        # Encoding for T5 output (decoder prompt)
        decoder_input = item['decoder_input']
        decoder_encoding = self.tokenizer(
            decoder_input,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors="pt"
        )

        return {
            "input_ids": input_ids.squeeze(),
            "attention_mask": encoder_encoding.attention_mask.squeeze(),
            "decoder_input_ids": decoder_encoding.input_ids.squeeze(),
            "labels": labels.squeeze(),
            "target_label": self.target_labels[idx]

        }

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.2 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
# Load T5 tokenizer and model
tokenizer = T5Tokenizer.from_pretrained('t5-small')
model_TST = T5ForConditionalGeneration.from_pretrained('t5-small')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
train_data, val_data = train_test_split(t5_data, test_size=0.1, random_state=42)
train_dataset = T5StyleTransferDataset(tokenizer, train_data)
val_dataset = T5StyleTransferDataset(tokenizer, val_data)

# %%
from torch.nn.functional import cosine_similarity

def content_preservation_loss(generated_text, original_text, tokenizer):
    gen_embeddings = tokenizer.encode(generated_text, return_tensors="pt").to('cuda')
    orig_embeddings = tokenizer.encode(original_text, return_tensors="pt").to('cuda')
    cos_sim = cosine_similarity(gen_embeddings, orig_embeddings)
    return 1 - cos_sim

# %%
def style_discrimination_loss(classifier_logits, true_labels):
    classifier_logits = classifier_logits.tolist()
    classifier_logits = 1 if classifier_logits[0] > classifier_logits[1] else 0
    print(classifier_logits)
    print(true_labels)
    criterion = nn.CrossEntropyLoss()
    return criterion(classifier_logits, true_labels)

# %%
class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False):
        outputs = model(**inputs)
        loss = outputs.loss

        # style discrimination loss part
        generated_texts = model.generate(inputs['input_ids'])
        classifier_outputs = predict(generated_texts)

        discrimination_loss = style_discrimination_loss(classifier_outputs, inputs['target_label'])

        # Content preservation loss
        content_loss = content_preservation_loss(generated_texts, inputs['input_ids'], tokenizer)

        # Combine the losses
        total_loss = loss + 0.5*discrimination_loss + 0.5*content_loss

        return (total_loss, outputs) if return_outputs else total_loss

# %%
# '''
# #training loop
# import tqdm
# train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=4)

# model = T5ForConditionalGeneration.from_pretrained('t5-small')
# optimizer = AdamW(model.parameters(), lr=5e-5)

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model.to(device)

# num_epochs = 3
# for epoch in range(num_epochs):
#     model.train()
#     total_loss = 0
#     for batch in tqdm(train_loader, desc=f"Training Epoch {epoch + 1}"):
#         optimizer.zero_grad()

#         input_ids = batch['input_ids'].to(device)
#         attention_mask = batch['attention_mask'].to(device)
#         decoder_input_ids = batch['decoder_input_ids'].to(device)
#         labels = batch['labels'].to(device)

#         outputs = model(input_ids=input_ids, attention_mask=attention_mask,
#                         decoder_input_ids=decoder_input_ids, labels=labels)
#         loss = outputs.loss
#         total_loss += loss.item()
#         loss.backward()
#         optimizer.step()

#     avg_train_loss = total_loss / len(train_loader)
#     print(f"Average training loss: {avg_train_loss:.4f}")

#     # Validation Phase
#     model.eval()
#     total_eval_loss = 0
#     with torch.no_grad():
#         for batch in tqdm(val_loader, desc=f"Validation Epoch {epoch + 1}"):
#             input_ids = batch['input_ids'].to(device)
#             attention_mask = batch['attention_mask'].to(device)
#             decoder_input_ids = batch['decoder_input_ids'].to(device)
#             labels = batch['labels'].to(device)

#             outputs = model(input_ids=input_ids, attention_mask=attention_mask,
#                             decoder_input_ids=decoder_input_ids, labels=labels)
#             loss = outputs.loss
#             total_eval_loss += loss.item()

#     avg_val_loss = total_eval_loss / len(val_loader)
#     print(f"Average validation loss: {avg_val_loss:.4f}")
#     '''

# %%
# from transformers import Trainer, TrainingArguments
# class StyleTransferTrainer(Trainer):
#     def compute_loss(self, model, inputs, return_outputs=False):
#         labels = inputs.pop("labels")
#         outputs = model(**inputs, labels=labels)
#         loss = outputs.loss
#         return (loss, outputs) if return_outputs else loss

# %%
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=4,
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    evaluation_strategy="epoch"
)

# %%
# trainer for training
trainer = Trainer(
    model=model_TST,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='12776' max='12776' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12776/12776 1:15:18, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.401800</td>
#       <td>5.249876</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.980000</td>
#       <td>5.063471</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.337400</td>
#       <td>4.911224</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.195700</td>
#       <td>4.825493</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=12776, training_loss=5.452163243637132, metrics={'train_runtime': 4519.1596, 'train_samples_per_second': 11.308, 'train_steps_per_second': 2.827, 'total_flos': 6916507422425088.0, 'train_loss': 5.452163243637132, 'epoch': 4.0})

# %%
# !pip install transformers[torch]
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.1)
# Requirement already satisfied: torch!=1.12.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.1.0+cu121)
# Collecting accelerate>=0.20.3 (from transformers[torch])
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers[torch]) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.10->transformers[torch]) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.10->transformers[torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.10->transformers[torch]) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.25.0

# %%
print(trainer.evaluate())
# Out:
#     <div>
#
#       <progress value='355' max='355' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [355/355 00:40]
#     </div>
# {'eval_loss': 4.863582611083984, 'eval_runtime': 40.5035, 'eval_samples_per_second': 35.059, 'eval_steps_per_second': 8.765, 'epoch': 4.0}

# %%
def style_transfer(model, tokenizer, sentence, max_length=512, device='cpu'):
    # Set the model to evaluation mode
    model_TST.eval()
    print(sentence)
    pre_classification = predict(sentence).tolist()
    style = 'Shakespearean' if pre_classification[0] > pre_classification[1] else 'news'
    # Prepare the text input for the encoder
    encoder_inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=max_length)
    encoder_input_ids = encoder_inputs.input_ids.to(device)
    encoder_attention_mask = encoder_inputs.attention_mask.to(device)

    # Generate style-specific decoder input IDs
    style_prompt = f"Generate {style} style:"
    decoder_inputs = tokenizer(style_prompt, return_tensors="pt", padding=True, truncation=True, max_length=max_length)
    decoder_input_ids = decoder_inputs.input_ids.to(device)

    # Use the model's generate function to perform generation
    with torch.no_grad():
        generated_ids = model_TST.generate(
            input_ids=encoder_input_ids,
            attention_mask=encoder_attention_mask,
            decoder_input_ids=decoder_input_ids,
            max_length=max_length,
            num_beams=1,  # You can change num_beams to a higher number for beam search
            early_stopping=True
        )

    # Decode the generated sequence to a string
    generated_text = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
    generated_text = generated_text.split(':', 1)[1]
    print("generated_text:", generated_text)
    print("============")
    return generated_text

style_transfer(model_TST, tokenizer, "ckingham creaseth", device=device)
# Out:
# ckingham creaseth
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:418: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# generated_text: creaseth ckingham creasethth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth ckingham creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth crease
# ============
# 'creaseth ckingham creasethth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth ckingham creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth creaseth crease'

# %%
def wrapper(sentence):
    return style_transfer(model_TST, tokenizer, sentence, device=device)
test_df['transfer_result'] = test_df['sentence'].apply(wrapper)
# Out:
# AUFIDIUS:I have not deserved it
# generated_text: I have not deserved it, but it has been deserved by me.I have not deserved it, but it has been deserved by me.
# ============
# LARTIUS:So, let the ports be guarded: keep your duties,As I have set them down
# generated_text:  let the ports be guarded: keep your duties,I have set them down down as I have set them down. keep your duties,I have set them down down as I have set them down down. keep your duties,I have set them down down as I have set them down down.
# ============
# frustrated by heavy tax burdens and rising costs
# generated_text:  tax burdens and rising costs, the economy is a big problem for the economy, and the rising costs of the economy, which is a major problem for the economy, and the economy, which is a major problem for the economy, and the economy, which is a major factor in the economy’s growth in the economy.
# ============
# Tunisia weathered the Arab Spring and has been buoyed by its tourism industry
# generated_text:  has been buoyed by its tourism industry as it has been buoyed by its tourism industry industry. Tunisia has been buoyed by its tourism industry industry as well as its tourism industry.
# ============
# He says it will be a mix of classic hits and fan favorites
# generated_text:  will be a mix of classic hits and fan favorites, he says he says he will be a mix of classic hits and fan favorites.
# ============
# There might you have beheld onejoy crown another, so and in such manner that itseemed sorrow wept to take leave of them, for theirjoy waded in tears
# generated_text: held onejoy crown another, so and in such manner that itseemed sorrow wept to take leave of them, for theirjoy crown was waded in tears in tears, and theirjoy waded in tears in tears, and theirjoy waded in tears in tears, and theirjoy waded in tears in tears waded in tears waded in tears waded in tears waded in tears waded in tears waded in tears w
# ============
# Deportivo and Espanyol next on the list
# generated_text:  are the top five of the list - the list is the city of Deportivo and Espanyol - the city of Espanyol - the city's list - the city's list of top names - the city's list of top names - the city's list of top names - the city's city of Deportivo and Espanyol - the city's list - the city's list of top
# ============
# What foreign liberty-seekers want from us is moral validation of their cause, he writes
# generated_text:  from us is moral validation of their cause, he writes, he writes. What foreign liberty seekers want from us is moral validation of their cause, he writes. he says the reason foreign liberty seekers seek is moral validation of their cause, he writes. he says the reason is moral validation of their cause, he writes, is moral validation of their cause, he writes.
# ============
# A Scotsman on holiday captured the strange encounter from his deck
# generated_text:  on holiday captured the strange encounter from his deck from his deck. The strange encounter was captured from his deck by a Scotsman on holiday.
# ============
# DUCHESS OF YORK:I will be mild and gentle in my speech
# generated_text: YORK:I will be mild and gentle in my speech in my speech, and in my speech will be gentle and gentle in my speech.
# ============
# Third Citizen:When clouds appear, wise men put on their cloaks;When great leaves fall, the winter is at hand;When the sun sets, who doth not look for night?Untimely storms make men expect a dearth
# generated_text: :On Thursday, sir? the time is very short, the time is very short, and the time is very short, and the time is very short.
# ============
# Patient use of unnecessary antibiotics will be curtailed
# generated_text: s will be reduced to a minimum of time if used with unnecessary antibiotics.
# ============
# DION:The violent carriage of itWill clear or end the business: when the oracle,Thus by Apollo's great divine seal'd up,Shall the contents discover, something rareEven then will rush to knowledge
# generated_text:  carriage of itWill clear or end the business: when the oracle,Thus by Apollo's great divine seal'd up,Shall the contents discover, something rareEven then will rush to knowledge, and then will rush to knowledge, and then will be able to find, something rareEven then will rush to knowledge, and then will be able to find the truth.when the oracle,Thus by Apollo's great divine seal'd up,the contents of it will
# ============
# There are conflicting reports on a British man held in Kenya for questioning
# generated_text:  on a British man held in Kenya for questioning in Kenya for questioning. a British man is believed to have been arrested in Kenya for questioning in Kenya.
# ============
# Look, I am going:Commend me to my wife
# generated_text:  am going::I am going::Commend me to my wife, my wife, and I will come:Commend me to my wife. I am going:Commend me to my wife, my wife, and I will be going:Commend me to my wife. I am going:Commend me to my wife, my wife, and I will be going:Commend me to my wife, my wife, and I will be going:Commend me to my wife, my wife, and I will
# ============
# YORK:If 'twere not she, I cannot tell who told me
# generated_text: 'twere not she, I cannot tell who told me who told me me who told me me. I cannot tell who told me who told me me.
# ============
# CORIOLANUS:It is a purposed thing, and grows by plot,To curb the will of the nobility:Suffer't, and live with such as cannot ruleNor ever will be ruled
# generated_text: t is a purposed thing, and grows by plot, and grows by plot, to curb the will of the nobility:Suffer't, and live with such as cannot ruleNor ever will be ruled by the nobility, and live with such as cannot rule.It is a purposed thing, and grows by plot, and grows by plot, and grows by plot,To curb the will of the nobility:It is a purposed thing, and grows
# ============
# Nick Clegg had vetoed the plan over fears it would tie judges' hands
# generated_text: d the plan over fears it would tie judges' hands on him. he said he was worried it would tie judges' hands on him if he had a chance to tie judges' hands. he said he had vetoed the plan over fears it would tie judges' hands on him.
# ============
# But big freeze set to give way to drizzle, clouds and even sunshine
# generated_text:  freezes to give way to drizzle, clouds and even sunshine. But big freeze set to give way to drizzle, clouds and even sunshine.
# ============
# GLOUCESTER:If you thrive well, bring them to Baynard's Castle;Where you shall find me well accompaniedWith reverend fathers and well-learned bishops
# generated_text:  you thrive well, bring them to Baynard's Castle;Where you shall find me well accompaniedWith reverend fathers and well-earned bishops, GLOUCESTER:If you thrive well, bring them to Baynard's Castle;Where you shall find me well accompaniedWith reverend fathers and well-earned bishops, GLOUCESTER:If you thrive well, bring them to Baynard's Castle;Where you shall find me well accompaniedWith reverend
# ============
# CNN shoots first video inside Saddam Hussein's cell, gets a look at his journal
# generated_text:  inside his cell, gets a look at his journal journal, and takes a look at his journal journal.
# ============
# A military plane brings in rice and water, transports out injured
# generated_text:  brings in rice and water, transports out injured injured. A military plane brings in rice and water, transports out injured injured.
# ============
# SICINIUS:Here's he that would take from you all your power
# generated_text: s he who would take from you all your power all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power, all your power,
# ============
# More than 300 Australian and overseas companies shrink their tax bills by routing their profits through the tiny European nation
# generated_text:  overseas companies shrink their tax bills by routing profits through the tiny European nation. More than 300 Australian and overseas companies shrink their tax bills by routing profits through the tiny European nation.
# ============
# Peter McColgan's testimony not considered reliable
# generated_text:  was considered reliable, but was considered reliable. he was not a reliable testimony of Peter McColgan's testimony not considered reliable.
# ============
# BAPTISTA:And yet you halt not
# generated_text:  yet you halt not not to be a good man, and yet you halt not not to be a good man, and yet you halt not not to be a good man, and yet you halt not not to be a good man, and yet you halt not not to be a good man, and yet you halt not not to be a good man, and yet you halt not not to be a good man, and yet you halt not not to be
# ============
# O, who hath any cause to mourn but I?QUEEN MARGARET:If ancient sorrow be most reverend,Give mine the benefit of seniory,And let my woes frown on the upper hand
# generated_text:  MARGARET:Is it a cause to mourn but I?QUEEN MARGARET:Is ancient sorrow most reverend,And give my benefit of seniory,And let my woes sown on the upper hand,And let my woes sown on the upper hand,And let my woes sown on the upper hand,And let my woes sown on the upper hand,And let my woes sown on the upper
# ============
# POMPEY:No, indeed, sir, not of a pin; you are therein inthe right: but to the point
# generated_text:  indeed, sir, not of a pin; you are therein inthe right: but to the point point, you are therein inthe right: but to the point point, you are therein inthe right: but to the point point, to the point point, to the point point, to the point point, to the point point, to the point point, to the point point, to the point point, to the point point, to the point point, to the point point, to the point point
# ============
# Gaunt was also told to pay Miss Bolland £500 compensation for bruising
# generated_text:  told to pay £500 compensation to Miss Bolland for bruising. he was also told to pay £500 compensation to Miss Bolland for bruising.
# ============
# At least eight rogues, thieves and gem traders have at some point laid claim to the 840-pound rock that was culled from the jungle in 2001
# generated_text:  thieves and gem traders have laid claim to the rock that was culled from the jungle in 2001. The rock was culled from the jungle in 2001 and was culled from the jungle in 2001.
# ============
# MARCIUS:Sir, it is;And I am constant
# generated_text: ir, it is;And I am constant constant;And I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant.I am constant constant
# ============
# Give me those flowers
# generated_text:  those flowers, and give me them flowers.
# ============
# He told authorities he'd been drinking heavily for 50 days
# generated_text:  authorities he'd been drinking heavily for 50 days. he told authorities he'd been drinking heavily for 50 days.
# ============
# O, thus she stood,Even with such life of majesty, warm life,As now it coldly stands, when first I woo'd her!I am ashamed: does not the stone rebuke meFor being more stone than it? O royal piece,There's magic in thy majesty, which hasMy evils conjured to remembrance andFrom thy admiring daughter took the spirits,Standing like stone with thee
# generated_text:  with such life of majesty, warm life,and coldly stands,when first I woo'd her!I am ashamed: does not the stone rebuke meFor being more stone than it?O royal piece,there's magic in thy majesty, and it's magic in thy majesty, and warm life,and so she stood,even with such life of majesty, warm life,and so she stood,and so she
# ============
# Hadzic is wanted for war crimes and crimes against humanity
# FLORIZEL:O, that must beI' the virtue of your daughter: one being dead,I shall have more than you can dream of yet;Enough then for your wonder
# generated_text:  that must beI' the virtue of your daughter: one being dead,I shall have more than you can dream of yet;O, that must beI' the virtue of your daughter; one being dead,I shall have more than you can dream of yet;Enough then for your wonder wonders, if you are to be dead,I shall have more than you can dream of yet;At the time of your wonders, you will have more than you can dream of yet;At the time of
# ============
# Tahrir Square campers dwindle in numbers after names are leaked
# generated_text: ers dwindle in numbers after names are leaked...............................................
# ============
# Oil shale is found in rocks just 30 metres underground
# generated_text:  found in rocks 30 metres underground, just 30 metres underground. shale is found in rocks in rocks 30 metres underground.
# ============
# Reports claim the consumer drones could launch ‘late next year’Device would rival drones from likes of Parrot and DJI
# generated_text:  the consumer drones could launch ‘late next year’Device would rival drones from like Parrot and DJII. The drones could launch ‘late next year’Device would rival drones from like Parrot and DJII.
# ============
# KING EDWARD IV:See that he be convey'd unto the Tower:And go we, brothers, to the man that took him,To question of his apprehension
# generated_text: Is he be conveyed unto the Tower:And go we, brothers, to the man who took him,To question of his apprehension, to question of his apprehension, to question of his apprehension, to question of his apprehension, to question of his apprehension, to question of his apprehension, to question of his apprehension, to question of his apprehension, to
# ============
# Katherine Willoughby could have been Henry's last wife  but king resisted
# generated_text:  be Henry's wife, but king resisted her decision, but king resisted the decision, but king resisted the decision. king said she was the last wife of Henry's, but king resisted the decision. king said she was the last wife of Henry's, but king resisted the decision.
# ============
# GLOUCESTER:Go, after, after, cousin Buckingham
# generated_text: Go, after, after, after, cousin Buckinghamingham:Go, after, after, after, cousin Buckinghamingham:Go, after, after, after, cousin Buckinghamingham:Go, after, after, after, cousin Buckinghamingham:Go, after, after, after, cousin Buckinghamingham:Go, after, after, after, cousin Buckinghamingham:Go, after, after, after, cousin Buckinghamingham:Go, after, after, after, after, cousin Buckinghamingham:Go
# ============
# Video of the cute promposal has over three million views since being posted to Facebook on Tuesday
# generated_text:  promposal has over three million views since being posted to Facebook on Tuesday.
# ============
# KING LEWIS XI:Then, England's messenger, return in post,And tell false Edward, thy supposed king,That Lewis of France is sending over masquersTo revel it with him and his new bride:Thou seest what's past, go fear thy king withal
# generated_text: II:And then, England's messenger, return in post,And tell false Edward, thy supposed king,And tell false Edward, thy supposed king,And tell false Edward, thy supposed king,That Lewis of France is sending over masquers,And revel it with him and his new bride:Thou seest what's past, go fear thy king withal:Thou seest what's past, go fear thy king
# ============
# I will not sleep, Hortensio, till I see her;And therefore let me be thus bold with youTo give you over at this first encounter,Unless you will accompany me thither
# generated_text:  sleep, Hortensio, till I see her;but let me be so bold with you, Hortensio, till I see her;and therefore let me be so bold with you, and be so bold with you, unless you will accompany me thitherither, thither, thither, thither, thither, thither, thither, thither, if you will accompany me thither, thither, thither,
# ============
# Clown:What, by a horseman, or a footman?AUTOLYCUS:A footman, sweet sir, a footman
# generated_text:  by horseman, or footman?AUTOLYCUS:A footman, sweet sir, a footman, a footman, a footman, a footman, a footman, a footman, a footman, a footman, a footman, a footman, a footman, a footman, a footman, a footman, a footman, a footman, a footman,
# ============
# Scored the winning goal for Barcelona in the 1992 European Cup final
# generated_text:  in the 1992 European Cup final of the 1992 European Cup final.
# ============
# GREMIO:But thine doth fry
# generated_text:  thine doth fry fry, but thine doth fry fry.
# ============
# The gunman's wife escaped the home with their two toddlers and called 911, and an hour later, his sister emerged saying she had been hiding
# generated_text:  wife escaped the home with their two toddlers and called 911. an hour later, his sister emerged saying she had been hiding in hiding.
# ============
# Leave me solely: go,See how he fares
# generated_text: , go,See how he fares,See how he fares.
# ============
# Mr Jago, 45, performed first aid despite not doing it since he was a child
# generated_text: , 45, performed first aid despite not doing it since he was a child. he performed first aid despite not doing it since he was a child. he performed first aid despite not doing it since he was a child. he performed first aid despite not doing it since he was a child.
# ============
# The Philippine-born actress had a part in "Pirates of the Caribbean: On Stranger Tides"She has a baby with 50 Cent, aka Curtis Jackson, now accused of kicking her
# generated_text:  Stranger Tides"The actress played a part in "Pirates of the Caribbean: On Stranger Tides"The actress had a part in "Pirates of the Caribbean: On Stranger Tides" "The Caribbean: On Stranger Tides":The movie, which stars in "The Caribbean: On Stranger Tides," plays a part in "The Caribbean: On Stranger Tides" "The Caribbean:" "The Caribbean:" "The Caribbean: On
# ============
# MERCUTIO:A challenge, on my life
# generated_text: I challenge, on my life, on my life, on my life, on my life.I challenge, on my life, on my life, on my life.I challenge, on my life, on my life, on my life.I challenge, on my life, on my life, on my life.I challenge, on my life, on my life, on my life, on my life.I challenge, on my life, on my life, on my life, on my life, on my life, on
# ============
# These tears are my sweet Rutland's obsequies:And every drop cries vengeance for his death,'Gainst thee, fell Clifford, and thee, falseFrenchwoman
# generated_text: s obsequies of sweet Rutland's obsequies:And every drop cries vengeance for his death,'Gainst thee, fell Clifford, and thee, falseFrenchwoman,'And every drop cries vengeance for his death,'And every drop cries vengeance for his death,'And every drop cries vengeance for his death,'And every drop c
# ============
# It features details for buses, trains, tubes, trams and ferries across the UK
# generated_text:  for buses, trains, tubes, trams and ferries across the UK. It features details for buses, trains, tubes, trams and ferries across the UK.
# ============
# Cominius,Droop not; adieu
# generated_text: inius,Droop not; adieu; adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu, adieu,
# ============
# Search giant set to test new methods - but refuses to reveal what they are
# generated_text:  to test new methods - but refuses to reveal what they are - but refuses to reveal what they are - but refuses to reveal what they are.
# ============
# KING HENRY VI:Let's levy men, and beat him back again
# generated_text: RY VI:Let's levy men, and beat him back again again, and beat him back again.Let's beat him back again.
# ============
# DUKE VINCENTIO:Many that are not madHave, sure, more lack of reason
# generated_text: It is not mad, sure, more lack of reason than reason, DUKE VINCENTIO:Many who are not madHave, sure, more lack of reason than reason, more lack of reason, more lack of reason, more lack of reason, more lack of reason, more lack of reason, more lack of reason, more lack of reason, more lack of reason, more lack of reason, more reason, more lack of reason, more reason, more reason, more reason, more reason,
# ============
# The patent was filed by a Google software engineer on behalf of the firm
# generated_text:  by a Google software engineer on behalf of the firm's firm. The patent was filed by a software engineer on behalf of the firm's firm.
# ============
# Guests included Theo Walcott, Gareth Bale and Craig Bellamy
# generated_text: th Bale and Craig Bellamy included guests including Theo Walcott, Gareth Bale and Craig Bellamy.
# ============
# What, ho! apothecary!Apothecary:Who calls so loud?ROMEO:Come hither, man
# generated_text:  apothecary!Apothecary:Who calls so loud?ROMEO:Come hither, man!Apothecary:Who calls so loud?ROMEO:Come hither, man!Apothecary:Who calls so loud?Apothecary:Who calls so loud?Apothecary:Who calls so loud?Apothecary:Who calls so loud?Apothecary:Who calls so loud?ROMEO:Com
# ============
# Has long been at odds with U
# generated_text:  in conflict with U.S.
# ============
# KING RICHARD II:Go, Bushy, to the Earl of Wiltshire straight:Bid him repair to us to Ely HouseTo see this business
# generated_text: I:Go, Bushy, to the Earl of Wiltshire straight:Bid him repair to us to Ely HouseTo see this business, we will see this business.It is a good business to see this business.It is a good business to see this business.It is a good business to see this business.It is a good business to see this business.It is a good business to see this business.It is a good business to see
# ============
# Villa considering £5million bid for the 23-year-old centre back
# generated_text: s considering £5million bid for the centre back - who is currently a target for the centre back. the centre back is currently undergoing a £5million move to Villa in the summer.
# ============
# This can hinder optimum brain development and lead to depression in children
# generated_text: t development and lead to depression in children. This can hinder optimal brain development and lead to depression in children.
# ============
# CLEOMENES:Good madam,--PAULINA:I have done
# generated_text: Good madam,--PAULINA:I have done it, and have done it.I have done it.I have done it.I have done it.I have done it.I have done it.I have done it.I have done it.I have done it.I have done it.I have done it.I have done it.I have done it.I have done it.I have done it.I have done it.
# ============
# I am too old to fawn upon a nurse,Too far in years to be a pupil now:What is thy sentence then but speechless death,Which robs my tongue from breathing native breath?KING RICHARD II:It boots thee not to be compassionate:After our sentence plaining comes too late
# generated_text:  old to fawn upon a nurse,Too far in years to be a pupil now:What is thy sentence then but speechless death,Which robs my tongue from breathing native breath?KING RICHARD II:It boots thee not to be compassionate:After our sentence plaining comes too late,It boots thee not to be compassionate:I am too old to fawn upon a nurse,I am too old to fa
# ============
# Most welcome!First Conspirator:How is it with our general?AUFIDIUS:Even soAs with a man by his own alms empoison'd,And with his charity slain
# generated_text: Conpirator:How is it with our general?AUFIDIUS:And so so,As with a man by his own alms empoison'd,And with his charity slain,with his charity slain,with his charity slain,with his charity slain,with his charity slain,with his charity slain,with his charity slain,with his charity slain,with his
# ...
# ============
# SICINIUS:Why, so he did, I am sure
# generated_text: I think he did, so he did, I am sure, and I am sure he will be a good man, and I am sure he will be a good man, and he did it, so he did, so he did, I am sure.
# ============
# Robert Fitts says 1934 tour by American all-stars led to first pro teams
# generated_text:  his 1934 tour by American all-stars led to first pro teams, he says he says he was a big fan of the 1930s and was a great player in the world. he says 1934 tour by the American all-stars led to first pro teams, he says he says he was a big fan of the 1930s and was a big fan of the 1930s.
# ============
# Previous complaint to police had not been pursued, but she contacted again
# generated_text:  pursued, but she contacted police again, but she contacted again.
# ============
# Nike joined up with Brasilian designer Pedro Lourenço to create collection
# generated_text: 's Pedro Lourenço has created collection for Nike. Nike joined up with brasilian designer Pedro Lourenço to create collection collection.
# ============
# Sound trumpets! let our bloody colours wave!And either victory, or else a grave
# generated_text:  bloody colours wave!Let our bloody colours wave!And either victory, or else a grave grave!And either victory, or else else a grave grave!And a grave grave, or a grave grave.And a grave grave, or a grave grave.And a grave grave, or a grave grave.And a grave grave.
# ============
# France's Sarkozy says Jobs was "one of the great figures of our time"Jobs "transformed the way we work and play," British PM David Cameron says
# generated_text:  says Jobs was "one of the great figures of our time"Jobs "transformed the way we work and play," British PM David Cameron says. "sarkozy says Jobs was one of our great figures of our time"Jobs "transformed the way we work and play," British PM David Cameron says.
# ============
# COMINIUS:I think 'twill serve, if heCan thereto frame his spirit
# generated_text: I think 'twill serve, if heCan, thereto frame his spirit, if heCan, he can frame his spirit.I think 'twill serve, if heCan, heCan, he can serve, if heCan, he can serve, if heCan, thereto frame his spirit.
# ============
# We would as willingly give cure as know
# generated_text:  willingly give cure as know know, but we would as willingly give cure as know know if we would give cure as know if we would give cure as know if we would give cure as know if we would give cure as know if we would give cure as we would as willingly give cure as know know.
# ============
# process
# generated_text:
# ============
# Authorities pledge crackdown after spate of similar incidents
# generated_text:  crackdown on the case after spate of similar incidents.
# ============
# Stayed  for more drinks, then paid off second $89
# generated_text: d for more drinks, then paid off second $89,000 off second $89, which was a bonus.
# ============
# Tiger Woods is out early if he wins his race to be fit for the year's final major
# generated_text:  early if he wins his race to be fit for the year's final major major. he is out early if he wins his race to be fit for the year's final major major major.
# ============
# Calum Chambers has played 35 times already for Arsenal this season
# generated_text: s has played 35 times for Arsenal this season. he has played 35 times for Arsenal this season.
# ============
# KING EDWARD IV:Away, I say; I charge ye, bear her hence
# generated_text: :I say, ye say; I charge ye, bear her hence, and bear her hence, ye, she is a good woman, and she is a good woman, and she is a good woman, and she is a good woman, and she is a good woman, and I have a good time to do it, and she is a good woman, and I have a good time to do it, and she is a good woman, and I
# ============
# During her many trips abroad the Air Force's 'famous Turkey taco sandwich' was her favorite
# generated_text:  abroad the 'famous Turkey taco sandwich' was her favorite favorite. During her many trips abroad the 'famous Turkey taco sandwich' was her favorite favorite. During her many trips abroad the 'famous Turkey taco sandwich' was her favorite favorite.
# ============
# There are also concerns about transport links and security arrangements
# generated_text:  concerns about transport links and security arrangements, as well as security arrangements.
# ============
# McLaren are returning to Honda with Japanese engine supplier back in F1 for first time in seven years
# generated_text:  return to Honda with Japanese engine supplier back in F1 for first time in seven years. McLaren are returning to Honda with Japanese engine supplier back in F1 for first time in seven years.
# ============
# Lord:Thou art a fool: if Echo were as fleet,I would esteem him worth a dozen such
# generated_text: ''a fool: if Echo were as fleet,I would esteem him worth a dozen of such a dozen if Echo were as fleet,I would esteem him worth a dozen if Echo were as fleet,I would esteem him worth a dozen such as a dozen if Echo were as fleet,I would esteem him worth a dozen if Echo were as fleet,I would esteem him worth a dozen such as a dozen if Echo were as fleet,
# ============
# Deaf woman was with eight-year-old son in Port Orange Post Office, Florida
# generated_text:  with eight-year-old son in Florida Post Office, Florida, with a deaf woman was with a deaf woman with son in Port Orange Post Office, Florida. She was with eight-year-old son in Florida, Florida, where she was spotted with her deaf wife and her son.
# ============
# A crown for York! and, lords, bow low to him:Hold you his hands, whilst I do set it on
# generated_text: ds, bow low to him:Hold you his hands, whilst I do set it on, whilst I do set it on on the ground, and set it on on the ground, and I set it on the ground.Hold you his hands, whilst I do set it on, and set it on on the ground, and I do set it on the ground.Hold you his hands, whilst I do set it on on the ground, and I do set it on
# ============
# Typhoon Phanfone hit central Japan on Monday, disrupting air and train travel
# generated_text:  Phanfone hit central Japan on Monday, disrupting air and train travel. he disrupted air and train travel in central Japan. typhoon Phanfone hit central Japan on Monday, disrupting air and train travel.
# ============
# Memphis Belle is the nickname given to crafts flown by 91st Bomb Group
# generated_text: d for crafts flown by 91st Bomb Group. Memphis Belle is the nickname given to crafts flown by 91st Bomb Group.
# ============
# First Huntsman:I will, my lord
# generated_text: i will, my lord, be the first huntsman:I will, my lord, be the first huntsman:I will, my lord, be the first huntsman of the year:I will, my lord, be the first huntsman of the year:I will, my lord, be the first huntsman of the year:I will, my lord, be the first huntsman of the year:I will, my
# ============
# LOVEL:Come, come, dispatch; 'tis bootless to exclaim
# generated_text: Come, come, dispatch; 'tis bootless to exclaim,'tis bootless to exclaim.'tis bootless to exclaim.'tis bootless to exclaim.'tis bootless to exclaim.
# ============
# TYBALT:What, drawn, and talk of peace! I hate the word,As I hate hell, all Montagues, and thee:Have at thee, coward!First Citizen:Clubs, bills, and partisans! strike! beat them down!Down with the Capulets! down with the Montagues!CAPULET:What noise is this? Give me my long sword, ho!LADY CAPULET:A crutch, a crutch! why call you for a sword?CAPULET:My sword, I say! Old Montague is come,And flourishes his blade in spite of me
# generated_text: I hate the word,As I hate hell, all Montagues, and thee:Have at thee, coward!First Citizen:Clubs, bills, and partisans! strike! beat them down!own with the Capulets! down with the Montagues!CAPULET:What noise is this? Give me my long sword, ho!LADY CAPULET:A crutch!What, drawn, and talk of peace! I hate the word,
# ============

# %%
def label_generated_text_pred(sentence):
    label_prob = predict(sentence, model, tokenizer, device)
    if label_prob.tolist()[0] > 0.5:
        label = 0
    else:
        label = 1
    return label
test_df['label_generated_pred'] = test_df['transfer_result'].apply(label_generated_text_pred)

# %%
def label_generated_text_real(original_label):
    if original_label == 0:
        label = 1
    else:
        label = 0
    return label
test_df['label_generated_real'] = test_df['label'].apply(label_generated_text_real)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(test_df['label_generated_real'], test_df['label_generated_pred'])
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
predict = test_df['label_generated_pred']
True_label = test_df['label_generated_real']
fpr, tpr, thresholds = roc_curve(True_label, predict)
auc = roc_auc_score(True_label, predict)
plt.plot(fpr, tpr, color='red', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
print(f'AUC: {auc}')
# Out:
# AUC: 0.04142980438671355

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(True_label, predict)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.041191381495564006
